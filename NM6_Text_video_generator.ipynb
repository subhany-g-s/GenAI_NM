# %%
# !pip install gradio requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 88.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 5.9 MB/s eta 0:00:00
# ...

# %%
OPENROUTER_API_KEY = "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"

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.6.0+cu124
# True

# %%
pip uninstall torch torchvision torchaudio
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Would remove:
#     /usr/local/bin/torchfrtrace
#     /usr/local/bin/torchrun
#     /usr/local/lib/python3.11/dist-packages/functorch/*
#     /usr/local/lib/python3.11/dist-packages/torch-2.6.0+cu124.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/torch/*
#     /usr/local/lib/python3.11/dist-packages/torchgen/*
# Proceed (Y/n)? y
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Would remove:
#     /usr/local/lib/python3.11/dist-packages/torchvision-0.21.0+cu124.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/torchvision.libs/libcudart.41118559.so.12
#     /usr/local/lib/python3.11/dist-packages/torchvision.libs/libjpeg.1c1c4b09.so.8
#     /usr/local/lib/python3.11/dist-packages/torchvision.libs/libnvjpeg.02b6d700.so.12
# ...

# %%
pip show diffusers
# Out:
# Name: diffusers
# Version: 0.32.2
# Summary: State-of-the-art diffusion in PyTorch and JAX.
# Home-page: https://github.com/huggingface/diffusers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/diffusers/graphs/contributors)
# Author-email: diffusers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, huggingface-hub, importlib-metadata, numpy, Pillow, regex, requests, safetensors
# Required-by:

# %%
pip install --upgrade diffusers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 55.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.32.2
#     Uninstalling diffusers-0.32.2:
#       Successfully uninstalled diffusers-0.32.2
# ...

# %%
pip install torch torchvision torchaudio <your_pytorch_install_command>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `pip install torch torchvision torchaudio <your_pytorch_install_command>'

# %%
pip install diffusers transformers accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 1.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
pip install google-generativeai

# %%
import torch
from diffusers import DiffusionPipeline
from diffusers.utils import export_to_video
import google.generativeai as genai
import os
from google.colab import files  # For downloading the video in Colab
import numpy as np

# --- 1. Configuration ---
# Replace with your actual Gemini API key
GEMINI_API_KEY = "AIzaSyAv3CuOBvXGZU0dU0sPryuuHF5Qyk-rGCk"  # <--- ENTER YOUR GEMINI API KEY HERE
# Specify the pretrained text-to-video diffusion model
MODEL_ID = "damo-vilab/text-to-video-ms-1.7b"  # Or try "cerspense/zeroscope_v2_576w"
# Use GPU if available (Colab provides a GPU)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
# Output video filename prefix
OUTPUT_PREFIX = "generated_video"

# --- 2. Initialize Gemini ---
genai_model = None  # Initialize to None, so we can check if it loaded
if GEMINI_API_KEY != "YOUR_GEMINI_API_KEY":  # Only try to configure if the key has been entered
    try:
        genai.configure(api_key=GEMINI_API_KEY)
        genai_model = genai.GenerativeModel('gemini-pro')
        print("Gemini API is configured.")
    except Exception as e:
        print(f"Error initializing Gemini API: {e}")
        print("Continuing without Gemini.  Provide a valid API key for Gemini to be used.")

# --- 3. Load Diffusion Pipeline ---
try:
    pipe = DiffusionPipeline.from_pretrained(MODEL_ID, torch_dtype=torch.float16)
    pipe = pipe.to(DEVICE)
    print(f"Diffusion pipeline loaded successfully on {DEVICE}.")
except Exception as e:
    print(f"Error loading model {MODEL_ID} on {DEVICE}: {e}")
    print("Please ensure you have the necessary libraries installed (diffusers, transformers, accelerate, torch).")
    print("You might also need to accept the model's terms of service on the Hugging Face Hub.")
    exit()

# --- 4. Main Function: Generate Video ---
def generate_video_from_text(prompt):

    refined_prompt = prompt

    # --- 4.1 Refine prompt with Gemini ---
    if genai_model: # use the initialized model, which could be None
        use_gemini = input("Do you want Gemini to refine the prompt? (yes/no): ").lower()
        if use_gemini == "yes":
            try:
                response = genai_model.generate_content(f"Refine or expand this text prompt for a text-to-video generation model to create a visually compelling video: '{prompt}'")
                refined_prompt = response.text
                print(f"Gemini-refined prompt: {refined_prompt}")
            except Exception as e:
                print(f"Error using Gemini API: {e}")
                print("Using the original prompt.")

    # --- 4.2 Generate video frames ---
    try:
        print(f"Generating video with prompt: '{refined_prompt}'...")
        video_output = pipe(refined_prompt)
        video_frames = video_output.frames
        print(f"Video frames generated. Type: {type(video_frames)}, Length: {len(video_frames)}")

        if isinstance(video_frames, np.ndarray):
            num_frames = video_output.frame_count if hasattr(video_output, 'frame_count') else 16 #gets the frame count.
            print(f"Number of frames: {num_frames}")
            print(f"Shape of video_frames: {video_frames.shape}") # Print the shape!
            if len(video_frames.shape) == 4:
                height, width, channels = video_frames.shape[1:]
                video_frames_list = np.split(video_frames, num_frames, axis=0)
                video_frames_list = [frame.squeeze(0) for frame in video_frames_list]
                print(f"Split video frames into a list of length: {len(video_frames_list)}")
            else:
                print("Unexpected shape for video_frames.  Not splitting.")
                video_frames_list = [video_frames] #wrap the video_frames in a list
        else:
            video_frames_list = video_frames
            print("Video frames is already a list.")

    except Exception as e:
        print(f"Error generating video: {e}")
        return None  # Important: Return None on error

    # --- 4.3 Save the video ---
    sanitized_prompt = prompt.replace(" ", "_")[:50]  # Sanitize for filename
    output_file = f"{OUTPUT_PREFIX}_{sanitized_prompt}.mp4"
    print(f"Saving video to: {output_file}")
    try:
        export_to_video(video_frames_list, output_file)
        print(f"Video saved to {output_file}")
        return output_file  # Return the file path on success
    except Exception as e:
        print(f"Error saving video: {e}")
        return None  # Return None on error

# --- 5. Run the script ---
if __name__ == "__main__":
    import numpy as np
    user_prompt = input("Enter the text prompt for the video: ")
    video_file_path = generate_video_from_text(user_prompt)  # Capture the return value

    if video_file_path:
        print(f"Video saved successfully to: {video_file_path}")
        # Download the video if running in Colab
        if "google.colab" in str(__import__('sys').modules):
            try:
                files.download(video_file_path)
                print(f"Video downloaded from Colab to your local machine.")
            except Exception as e:
                print(f"Error downloading video: {e}")
                print("Video was saved in Colab's file system.  You can download it manually from the file explorer.")
    else:
        print("Video generation and/or saving failed.")
# Out:
# Gemini API is configured.
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# Diffusion pipeline loaded successfully on cuda.
# Enter the text prompt for the video: bird flying in sky
# Do you want Gemini to refine the prompt? (yes/no): yes
# WARNING:tornado.access:404 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 505.81ms
# Error using Gemini API: 404 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.
# Using the original prompt.
# Generating video with prompt: 'bird flying in sky'...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Video frames generated. Type: <class 'numpy.ndarray'>, Length: 1
# Number of frames: 16
# Shape of video_frames: (1, 16, 256, 256, 3)
# ...

# %%
import torch
from diffusers import DiffusionPipeline
from diffusers.utils import export_to_video
import google.generativeai as genai
import os
from google.colab import files  # For downloading the video in Colab
import numpy as np

# --- 1. Configuration ---
# Replace with your actual Gemini API key
GEMINI_API_KEY = "AIzaSyAv3CuOBvXGZU0dU0sPryuuHF5Qyk-rGCk"  # <--- ENTER YOUR GEMINI API KEY HERE
# Specify the pretrained text-to-video diffusion model
MODEL_ID = "damo-vilab/text-to-video-ms-1.7b"  # Or try "cerspense/zeroscope_v2_576w"
# Use GPU if available (Colab provides a GPU)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
# Output video filename prefix
OUTPUT_PREFIX = "generated_video"

# --- 2. Initialize Gemini ---
genai_model = None  # Initialize to None, so we can check if it loaded
if GEMINI_API_KEY != "YOUR_GEMINI_API_KEY":  # Only try to configure if the key has been entered
    try:
        genai.configure(api_key=GEMINI_API_KEY)
        genai_model = genai.GenerativeModel('gemini-pro')
        print("Gemini API is configured.")
    except Exception as e:
        print(f"Error initializing Gemini API: {e}")
        print("Continuing without Gemini.  Provide a valid API key for Gemini to be used.")

# --- 3. Load Diffusion Pipeline ---
try:
    pipe = DiffusionPipeline.from_pretrained(MODEL_ID, torch_dtype=torch.float16)
    pipe = pipe.to(DEVICE)
    print(f"Diffusion pipeline loaded successfully on {DEVICE}.")
except Exception as e:
    print(f"Error loading model {MODEL_ID} on {DEVICE}: {e}")
    print("Please ensure you have the necessary libraries installed (diffusers, transformers, accelerate, torch).")
    print("You might also need to accept the model's terms of service on the Hugging Face Hub.")
    exit()

# --- 4. Main Function: Generate Video ---
def generate_video_from_text(prompt):
    """
    Generates a video from a text prompt using a diffusion model,
    optionally refining the prompt with Gemini.

    Args:
        prompt (str): The text prompt to generate the video from.

    Returns:
        str: The path to the saved video file, or None on error.
    """

    refined_prompt = prompt

    # --- 4.1 Refine prompt with Gemini ---
    if genai_model:  # use the initialized model, which could be None
        use_gemini = input("Do you want Gemini to refine the prompt? (yes/no): ").lower()
        if use_gemini == "yes":
            try:
                response = genai_model.generate_content(
                    f"Refine or expand this text prompt for a text-to-video generation model to create a visually compelling video: '{prompt}'"
                )
                refined_prompt = response.text
                print(f"Gemini-refined prompt: {refined_prompt}")
            except Exception as e:
                print(f"Error using Gemini API: {e}")
                print("Using the original prompt.")

    # --- 4.2 Generate video frames ---
    try:
        print(f"Generating video with prompt: '{refined_prompt}'...")
        video_output = pipe(refined_prompt)
        video_frames = video_output.frames
        print(f"Video frames generated. Type: {type(video_frames)}, Length: {len(video_frames)}")
        print(f"Shape of video_frames: {video_frames.shape}")  # Print the shape for debugging

        if isinstance(video_frames, np.ndarray):
            num_frames = video_output.frame_count if hasattr(video_output, 'frame_count') else 16  # gets the frame count.
            if len(video_frames.shape) == 5:  # Corrected check for expected shape
                batch_size, num_frames, height, width, channels = video_frames.shape
                video_frames_list = np.split(video_frames, batch_size, axis=0)  # Split along the batch dimension
                video_frames_list = [frame.squeeze(0) for frame in video_frames_list]
                print(f"Split video frames into a list of length: {len(video_frames_list)}")
            elif len(video_frames.shape) == 4:
                num_frames, height, width, channels = video_frames.shape
                video_frames_list = np.split(video_frames, num_frames, axis=0)
                video_frames_list = [frame.squeeze(0) for frame in video_frames_list]
                print(f"Split video frames into a list of length: {len(video_frames_list)}")
            else:
                print("Unexpected shape for video_frames.  Not splitting.")
                video_frames_list = [video_frames]  # wrap the video_frames in a list
        else:
            video_frames_list = video_frames
            print("Video frames is already a list.")

    except Exception as e:
        print(f"Error generating video: {e}")
        return None  # Important: Return None on error

    # --- 4.3 Save the video ---
    sanitized_prompt = prompt.replace(" ", "_")[:50]  # Sanitize for filename
    output_file = f"{OUTPUT_PREFIX}_{sanitized_prompt}.mp4"
    print(f"Saving video to: {output_file}")
    try:
        export_to_video(video_frames_list, output_file)
        print(f"Video saved to {output_file}")
        return output_file  # Return the file path on success
    except Exception as e:
        print(f"Error saving video: {e}")
        return None  # Return None on error


# --- 5. Run the script ---
if __name__ == "__main__":
    import numpy as np

    user_prompt = input("Enter the text prompt for the video: ")
    video_file_path = generate_video_from_text(user_prompt)  # Capture the return value

    if video_file_path:
        print(f"Video saved successfully to: {video_file_path}")
        # Download the video if running in Colab
        if "google.colab" in str(__import__('sys').modules):
            try:
                files.download(video_file_path)
                print(f"Video downloaded from Colab to your local machine.")
            except Exception as e:
                print(f"Error downloading video: {e}")
                print(
                    "Video was saved in Colab's file system.  You can download it manually from the file explorer."
                )
    else:
        print("Video generation and/or saving failed.")
# Out:
# Gemini API is configured.
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# Diffusion pipeline loaded successfully on cuda.
# Enter the text prompt for the video: eagle flying in sky
# Do you want Gemini to refine the prompt? (yes/no): no
# Generating video with prompt: 'eagle flying in sky'...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Video frames generated. Type: <class 'numpy.ndarray'>, Length: 1
# Shape of video_frames: (1, 16, 256, 256, 3)
# Split video frames into a list of length: 1
# Saving video to: generated_video_eagle_flying_in_sky.mp4
# Error saving video: Image must have 1, 2, 3 or 4 channels
# Video generation and/or saving failed.

# %%
import torch
from diffusers import DiffusionPipeline
from diffusers.utils import export_to_video
import google.generativeai as genai
import os
from google.colab import files  # For downloading the video in Colab
import numpy as np

# --- 1. Configuration ---
# Replace with your actual Gemini API key
GEMINI_API_KEY = "YOUR_GEMINI_API_KEY"  # <--- ENTER YOUR GEMINI API KEY HERE
# Specify the pretrained text-to-video diffusion model
MODEL_ID = "damo-vilab/text-to-video-ms-1.7b"  # Or try "cerspense/zeroscope_v2_576w"
# Use GPU if available (Colab provides a GPU)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
# Output video filename prefix
OUTPUT_PREFIX = "generated_video"

# --- 2. Initialize Gemini ---
genai_model = None  # Initialize to None, so we can check if it loaded
if GEMINI_API_KEY != "AIzaSyAv3CuOBvXGZU0dU0sPryuuHF5Qyk-rGCk":  # Only try to configure if the key has been entered
    try:
        genai.configure(api_key=GEMINI_API_KEY)
        genai_model = genai.GenerativeModel('gemini-pro')
        print("Gemini API is configured.")
    except Exception as e:
        print(f"Error initializing Gemini API: {e}")
        print("Continuing without Gemini.  Provide a valid API key for Gemini to be used.")

# --- 3. Load Diffusion Pipeline ---
try:
    pipe = DiffusionPipeline.from_pretrained(MODEL_ID, torch_dtype=torch.float16)
    pipe = pipe.to(DEVICE)
    print(f"Diffusion pipeline loaded successfully on {DEVICE}.")
except Exception as e:
    print(f"Error loading model {MODEL_ID} on {DEVICE}: {e}")
    print(
        "Please ensure you have the necessary libraries installed (diffusers, transformers, accelerate, torch)."
    )
    print("You might also need to accept the model's terms of service on the Hugging Face Hub.")
    exit()


# --- 4. Main Function: Generate Video ---
def generate_video_from_text(prompt):
    """
    Generates a video from a text prompt using a diffusion model,
    optionally refining the prompt with Gemini.

    Args:
        prompt (str): The text prompt to generate the video from.

    Returns:
        str: The path to the saved video file, or None on error.
    """

    refined_prompt = prompt

    # --- 4.1 Refine prompt with Gemini ---
    if genai_model:  # use the initialized model, which could be None
        use_gemini = input("Do you want Gemini to refine the prompt? (yes/no): ").lower()
        if use_gemini == "yes":
            try:
                response = genai_model.generate_content(
                    f"Refine or expand this text prompt for a text-to-video generation model to create a visually compelling video: '{prompt}'"
                )
                refined_prompt = response.text
                print(f"Gemini-refined prompt: {refined_prompt}")
            except Exception as e:
                print(f"Error using Gemini API: {e}")
                print("Using the original prompt.")

    # --- 4.2 Generate video frames ---
    try:
        print(f"Generating video with prompt: '{refined_prompt}'...")
        video_output = pipe(refined_prompt)
        video_frames = video_output.frames
        print(f"Video frames generated. Type: {type(video_frames)}, Length: {len(video_frames)}")
        print(f"Shape of video_frames: {video_frames.shape}")  # Print the shape for debugging

        if isinstance(video_frames, np.ndarray):
            num_frames = video_output.frame_count if hasattr(video_output, 'frame_count') else 16  # gets the frame count.
            if len(video_frames.shape) == 5:  # Corrected check for expected shape
                batch_size, num_frames, height, width, channels = video_frames.shape
                video_frames_list = np.split(video_frames, batch_size, axis=0)  # Split along the batch dimension
                video_frames_list = [
                    frame.squeeze(0) for frame in video_frames_list
                ]  # changed this line
                print(f"Split video frames into a list of length: {len(video_frames_list)}")
                if len(video_frames_list) > 0:
                    video_frames_list = video_frames_list[0]
                else:
                    print("Error: video_frames_list is empty after split.")
                    return None
            elif len(video_frames.shape) == 4:
                num_frames, height, width, channels = video_frames.shape
                video_frames_list = np.split(video_frames, num_frames, axis=0)
                video_frames_list = [frame.squeeze(0) for frame in video_frames_list]
                print(f"Split video frames into a list of length: {len(video_frames_list)}")
            else:
                print("Unexpected shape for video_frames.  Not splitting.")
                video_frames_list = [video_frames]  # wrap the video_frames in a list
        else:
            video_frames_list = video_frames
            print("Video frames is already a list.")

    except Exception as e:
        print(f"Error generating video: {e}")
        return None  # Important: Return None on error

    # --- 4.3 Save the video ---
    sanitized_prompt = prompt.replace(" ", "_")[:50]  # Sanitize for filename
    output_file = f"{OUTPUT_PREFIX}_{sanitized_prompt}.mp4"
    print(f"Saving video to: {output_file}")
    try:
        export_to_video(video_frames_list, output_file)
        print(f"Video saved to {output_file}")
        return output_file  # Return the file path on success
    except Exception as e:
        print(f"Error saving video: {e}")
        return None  # Return None on error


# --- 5. Run the script ---
if __name__ == "__main__":
    import numpy as np

    user_prompt = input("Enter the text prompt for the video: ")
    video_file_path = generate_video_from_text(user_prompt)  # Capture the return value

    if video_file_path:
        print(f"Video saved successfully to: {video_file_path}")
        # Download the video if running in Colab
        if "google.colab" in str(__import__('sys').modules):
            try:
                files.download(video_file_path)
                print(f"Video downloaded from Colab to your local machine.")
            except Exception as e:
                print(f"Error downloading video: {e}")
                print(
                    "Video was saved in Colab's file system.  You can download it manually from the file explorer."
                )
    else:
        print("Video generation and/or saving failed.")
# Out:
# Gemini API is configured.
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# Diffusion pipeline loaded successfully on cuda.
